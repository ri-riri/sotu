# %%
import os , os.path #osを読み込む
import sys
import pandas as pd #xlsxのファイルをcsvにする
import ast
import requests
from bs4 import BeautifulSoup
import json
from urllib import request
import csv
import collections
import glob
import re

# %%
#評価ワード読み込み
df1 = pd.read_excel("new評価ワード.xlsx", sheet_name=0)
df1.to_csv("new評価ワード.csv", index=False, header=None, encoding='utf_8_sig')
with open("new評価ワード.csv", encoding='utf_8_sig') as fp:
    
    #tuple型の評価ワード作成
    all_list = [] #all_lstはtuple型の評価ワード全部
    reader = csv.reader(fp)
    for row in reader: #rowはキヤノンらしいのかたまり
        word_list = [] #elementを追加していったもの
        for element in row: #elementはキヤノンらしいなどの単語1つ1つ
            if element != '': #空白削除
                word_list.append(element) #word_lstに追加していく
                word_tuple = tuple(word_list) #word_tupleはword_lstをタプル型に変換
        #print(word_tuple[0])
        all_list.append(word_tuple) #all_lstに追加していく
    #print(all_lst[0])


#all_lstをキーに0を値に取るdict型作成
mydict = {} #mydictはall_lstをキーに0を値に取る
for word in all_list:
    mydict[word] = 0
#print(mydict)

#txtファイルを読みこむ
files = glob.glob("./review/*/*/*_*_*.txt") #*に入るのは何でもいい
for file in files:
    f = open(file,"r")
    review = f.read() 
                        
    #mydictの値の部分をカウントしていく
    skip_flag = False #Falseは0と同じ
    for tuple_list in mydict: #tuple_listはキヤノンらしいのかたまり
        for item in tuple_list: #itemはキヤノンらしいなどの単語1つ1つ
            if review.count(item) > 0: #数えた結果が0より大きかったら
                skip_flag = True #Trueは1と同じ
                continue #次のitemに行く

        if skip_flag == True: #skip_flagがTrueなら処理実行
            skip_flag = False #Trueを踏んだらFalseに戻す
            mydict[tuple_list] += 1 #mydictの値のカウントを１増やす
            continue #次のtuple_listに行く
        f.close()

#print(len(files))
#print(mydict)
for myvalue in mydict.values():
    print(myvalue)
# Out:
# {('キヤノンらしい', 'キャノンらしい', 'キャノンらしく', 'キヤノンらしさ', 'キャノンっぽい', 'キヤノンぽい', 'Canonらしい', 'Canonらしく', 'canonらしさ'): 93, ('キヤノンらしくない',): 3, ('ニコンらしい', 'ニコンらしく', 'ニコンらしさ', 'ニコンっぽい', 'ニコン機らしい', 'Ｎｉｋｏｎらしい', 'NIKONらしい', 'Nikonらしい', 'Nikonらしく'): 90, ('フジらしい', 'FUJIFILMらしさ'): 16, ('ソニーらしい', 'SONYらしい'): 134, ('パナソニックらしい',): 9, ('LUMIXらしい', 'Lumixらしい'): 2, ('手になじむ', '手になじみ', '手に馴染む', '手によく馴染み', '手に馴染んで', '馴染み'): 268, ('なじめない', 'なじめなく', '馴染めず', '馴染めなかった', '慣れません'): 118, ('直感的', '直感操作', '直感的な操作', '直感的に', '直感的な'): 509, ('複雑な操作', '直感的とは言えない'): 14, ('ひと手間', '持ち替え'): 54, ('軽量', '軽量化', '軽く', '重くない'): 2694, ('重い', '重く', '重たい', '重さ', '重め'): 3390, ('小さい', '小さく', '小型', '小さすぎる'): 5252, ('大きい', '大きく', '大きめ', 'でかい', 'でかく', 'デカく', '大きすぎる'): 5147, ('使いやすい', '使い易い', '使いやすく', '使い易さ', '使い易く', '使用しやすい', 'やりやすい', '扱いやすい', '容易に操作', '優れた操作性', '快適な操作性'): 2882, ('使いづらい', '使い辛い', '使い難い', '使いにくく', 'やりづらい', 'やりにくい', 'しづらい', 'し辛い', 'しにくい', '使いこなせない', '難しい'): 2215, ('握りやすい', '握りやすく', '握り易く', '握りやすさ', '握りやすかった', '持ちやすい', 'つかみやすい', 'しっかり握れ', 'しっかり持てる'): 1063, ('持ちづらい', '持ちにくい', '握りにくい'): 421, ('滑りにくい',): 39, ('滑りやすい', 'すべりやすい', '滑ります', '滑ってしまう'): 158, ('落としそう',): 151, ('深いブリップ',): 1, ('ホールド感', 'ホールド性', '良いホールド感', '良好なホールド性', '心地よいホールド感', '素晴らしいホールド感', 'しっかりホールド', '十分なホールド感'): 9018, ('グリップ', 'グリップ性', 'しっかりしたグリップ'): 4080, ('見やすい', '見易く', 'みやすく'): 1741, ('見づらい', '見辛い', '見難い', '見にくい'): 583, ('覗きやすい',): 2, ('撮影しやすい', '撮りやすい'): 143, ('運びやすい', '持ち出しやすい', '文句なしの携帯性'): 76, ('押しづらい', '押しづらく', '押しにくい', '押しにくく'): 309, ('押し間違える',): 7, ('回しづらい', '回し辛い', '回しにくい'): 82, ('安い', '安かった', '安価', '低価格', '激安', '格安', '価格も下がり', '購入しやすい価格', 'お値打ち', 'リーズナブル', '値下がり'): 1432, ('高額', '高すぎ', '高すぎる'): 303, ('高級感', '安っぽくない', '安っぽくなく', 'ゴージャス'): 904, ('安っぽい', '安っぽさ', '安物っぽい', 'チープさ', '高級感が感じられません', '高級感はありません'): 415, ('違和感', '違和感を覚え'): 947, ('シンプル',): 1027, ('スッキリ', 'スッキリしたデザイン'): 256, ('スタイリッシュ',): 131, ('安定', '安定感'): 992, ('フィット', 'フィットする', '手にフィット', '手にフィットする'): 186, ('疲れない', '疲れません', '手がつかれません'): 69, ('疲れる', '疲れます', '疲れました', '手が疲れる', '手首に負担', '手首が痛く', '手が疲れ'): 109, ('目の疲労',): 1, ('自分好み',): 212, ('カスタマイズ', 'カスタマイズ性能', 'カスタム'): 1392, ('薄く', 'スリム'): 340, ('手軽', '手軽さ', 'お手軽'): 709, ('気軽',): 1291, ('コンパクト', 'スペースを取らない', 'スッキリと収まり', 'かさばらない'): 4303, ('かさばる', 'かさばり', 'かさばります', '邪魔', 'コンパクトとは言えません'): 798, ('高性能',): 478, ('新機能',): 72, ('追随性',): 16, ('AF性能',): 356, ('光学性能',): 38, ('タッチアンドドラッグ',): 9, ('慣れる', '慣れ', '慣れ易い', '直ぐに慣れます', '直ぐに慣れる', 'すぐに慣れる', 'すぐに慣れました'): 3503, ('慣れの問題',): 195, ('同じ操作性', '操作感が同じ', '操作系を踏襲', '慣れ親しんだ操作性'): 21, ('戸惑い', '戸惑う', '戸惑いはあり'): 457, ('分かりやすい', '迷うことなく'): 182, ('わかりづらい', '分かりにくい', 'わかりにくい', '理解不能'): 200, ('使い慣れたUI',): 2, ('かっこいい', 'かっこよく', 'カッコいい', 'カッコよく', 'カッコよさ', 'カッコよかった', 'カッコイイ', 'カッコ良い', 'カッコ良すぎ', '格好いい', '格好良い'): 1120, ('かっこ悪い', 'カッコ悪い', 'かっこよくない', 'カッコいいとは言えない'): 52, ('かわいい',): 92, ('洗練された', '洗練され', '洗練されている', '洗練されたデザイン'): 194, ('好きなデザイン',): 124, ('エッジの効いたデザイン',): 5, ('合理的なデザイン',): 2, ('無骨な', '無骨', '無骨なデザイン'): 211, ('角ばった', '角ばったデザイン'): 60, ('先進的な', '先鋭的'): 30, ('オシャレな', 'オシャレ', 'おしゃれ', 'お洒落な', 'お洒落'): 307, ('シックな', 'シック', 'シックなデザイン'): 380, ('未来的',): 19, ('グッドデザイン',): 3, ('直線的', '直線的なデザイン'): 56, ('カメラらしい', 'カメラらしいデザイン'): 191, ('無難', '無難なデザイン'): 237, ('遊び心',): 84, ('ユニークな',): 18, ('飽きない', '飽きないデザイン', '飽きのこないデザイン'): 81, ('クラシックな', 'クラシック', 'クラシカルな', 'クラシカル'): 482, ('メカニカルな', 'メカニカル', 'メカメカしく'): 103, ('メタリック',): 42, ('マグネシウムボディ',): 45, ('プラスチック', 'プラスチッキー'): 330, ('レトロな', 'レトロ'): 333, ('昭和',): 26, ('ノスタルジックな', '懐古'): 88, ('野暮ったく',): 20, ('高画質', '最高画質', '最高レベルの画質', '満足な画質', '素晴らしい画質', 'すばらしい画質', '十分な画質', '満足する画質', 'キレの良い画質'): 1387, ('そこそこの画質',): 36, ('ノイズ', 'ノイズが少し目立つ'): 2101, ('粗い', '粗さ'): 92, ('ボケない',): 38, ('便利',): 3430, ('不便',): 822, ('好き', '好み', '好感が持てる'): 4074, ('嫌い', '好みではありません'): 439, ('改善',): 1639, ('ファームアップ', 'ファームアップに期待', 'ファームアップを望みます'): 437, ('要改善',): 47, ('お気に入り', '気に入ってます', '気にいった'): 772, ('オススメ', 'おすすめ', 'お勧め'): 1828, ('オススメはしません', 'オススメもしません'): 6, ('満足', '大満足', '期待通り'): 5633, ('予想以上', '期待以上'): 279, ('魅力的', '魅力を感じ'): 514, ('感動',): 706, ('名機',): 173, ('優秀', '秀逸なカメラ',  ...
# 93
# 3
# 90
# 16
# 134
# 9
# 2
# 268
# 118
# 509
# 14
# 54
# 2694
# 3390
# 5252
# 5147
# 2882
# 2215
# 1063
# 421
# 39
# 158
# 151
# 1
# 9018
# 4080
# 1741
# 583
# 2
# 143
# 76
# 309
# 7
# 82
# 1432
# 303
# 904
# 415
# 947
# 1027
# 256
# 131
# 992
# 186
# 69
# 109
# 1
# 212
# 1392
# 340
# 709
# 1291
# 4303
# 798
# 478
# 72
# 16
# 356
# 38
# 9
# 3503
# 195
# 21
# 457
# 182
# 200
# 2
# 1120
# 52
# 92
# 194
# 124
# 5
# 2
# 211
# 60
# 30
# 307
# 380
# 19
# 3
# 56
# 191
# 237
# 84
# 18
# 81
# 482
# 103
# 42
# 45
# 330
# 333
# 26
# 88
# 20
# 1387
# 36
# 2101
# 92
# 38
# 3430
# 822
# 4074
# 439
# 1639
# 437
# 47
# 772
# 1828
# 6
# 5633
# 279
# 514
# 706
# 173
# 2745
# 532
# 2382
# 354
# 24
# 5076
# 267
# 140
# 112
# 1029
# 1150
# 4204
# 401
# 398
# 2624
# 2839
# 129
# 19
# 37
# 235
# 3317
# 13
# 433
# 1
# 60
# 167
# 1
# 135
# 169
# 1
# 138
# 219
# 35
# 73
# 262
# 6
# 30
# 8
# 590
# 2
# 90
# 52
# 89
# 41
# 195
# 1
# 64
# 113
# 78
# 968
# 1318
# 56
# 2
# 82
# 20
# 5
# 80
# 17
# 1
# 2
# 779
# 10
# 1
# 63
# 129
# 897
# 561
# 274
# 244
# 727
# 21
# 277
# 167
# 78
# 106
# 6
# 74
# 1
# 125
# 238
# 69
# 1082
# 20
# 36
# 1
# 161
# 160
# 9

# %%
file = open("評価ワード出現率.csv", "w", encoding = 'cp932', errors = 'ignore')
writer = csv.writer(file)
mylist = list(mydict.values())
keisan_list = []
for myvalue in mylist:
    keisan = myvalue*100/len(files)
    keisan_list.append(keisan)
    
writer.writerow(mylist)
writer.writerow(keisan_list)
file.close()
#print(mylist)

# %%
file.write(str(myvalue))
file.close()
